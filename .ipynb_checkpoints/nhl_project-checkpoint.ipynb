# %% [markdown]
# ## Some basic stuff

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
import pandas as pd

# %%
def getSoup(link):
    sleep(0.1)
    r = requests.get(link)
    return BeautifulSoup(r.text,'lxml')

# %% [markdown]
# ### Teams and their codes

# %% [markdown]
# #### Will be useful later on i think

# %%
codes = getSoup('https://nhl.cz/sezona/tymy')
codes
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="NHL.cz | Oficiální web českého hokeje. Extraliga, 1. liga, 2. liga, mládež, reprezentace, mistrovství světa, NHL, Champions Hockey League, evropské ligy" name="description"/>
# <meta content="BPA sport marketing a.s." name="Author"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="-1" http-equiv="expires"/>
# <meta content="document" name="resource-type"/>
# <meta content="general" name="rating"/>
# <meta content="global" name="distribution"/>
# <meta content="width=device-width, initial-scale=1,maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="www.pages06.net,hokej.cz,nhl.cz" name="com.silverpop.brandeddomains"/>
# <meta content="https://nhl.cz/images/logo/logo_m.png" property="og:image"/>
# <meta content="Týmy: Zápasy a statistiky | NHL.CZ" property="og:title"/>
# <meta content="NHL.cz | Oficiální web českého hokeje. Extraliga, 1. liga, 2. liga, mládež, reprezentace, mistrovství světa, NHL, Champions Hockey League, evropské ligy" property="og:description"/>
# <meta content="https://nhl.cz/sezona/tymy" property="og:url"/>
# <meta content="NHL.cz" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <title>Týmy: Zápasy a statistiky | NHL.CZ</title>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="https://nhl.cz/rss/nhl" rel="alternate" type="application/rss+xml"/>
# <script src="/js/vendor/modernizr-2.6.2-respond-1.1.0.min.js"></script>
# <link href="/webtemp/cssloader-7e5e6671eef0.css?1634812854" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var shownLeagues = [];</script>
# <link href="//w.cncenter.cz/styles/cnc-slot-sizes.min.css" id="cnc_global_css" rel="stylesheet"/>
# <script type="application/javascript">
#             window.__cncPageDefinition = window.__cncPageDefinition || {};
# 		</script>
# <script type="application/javascript">
# 			window.__cncPageDefinition.site = 'nhl';
# window.__cncPageDefinition.template = 'category';
# window.__cncPageDefinition.webType = 'responsive';
# window.__cncPageDefinition.forceArea = 'ostatni';
# window.__cncPageDefinition.keywords = '';
# 		</script>
# <script async="async" id="cnc_wrapper" src="//w.cncenter.cz/cnc-wrapper.min.js" type="application/javascript"></script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-NQH6GKW');</script>
# <!-- End Google Tag Manager -->
# <script async="async" id="cnc_cpex_cmp" src="//cdn.cpex.cz/cmp/v2/cpex-cmp.min.js"></script>
# <script async="async" id="cnc_cpex_loader" src="//cdn.cpex.cz/loader/v2/settings/cnc/nhl_cz.js"></script>
# <script async="async" id="cnc_gpt" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="async" id="cnc_cpex_prebid_settings" src="//ads.rubiconproject.com/prebid/22918_nhl.js"></script>
# </head>
# <body>
# <style>
# 			@media only screen and (max-width: 600px) {
#                 .ad-position-desktop {
#                     display: none;
#                 }
#             }
#
#             @media only screen and (min-width: 601px) {
#                 .ad-position-mobile {
#                     display: none;
#                 }
#             }
# 		</style>
# <!-- reklamní pozice (leaderboard_1) -->
# <div class="bcg-sys-top">
# <div class="banner">
# <!-- #Zona:Homepage;#ID:2x1;leaderboard_1 -->
# <div id="cnc_branding_creative_wrapper">
# <div class="cnc-ads cnc-ads--leaderboard">
# <div class="cnc-ads__within" id="cnc_leaderboard_1"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="branding-wrapper">
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# 			var js, fjs = d.getElementsByTagName(s)[0];
# 			if (d.getElementById(id)) return;
# 			js = d.createElement(s); js.id = id;
# 			js.src = "//connect.facebook.net/cs_CZ/sdk.js#xfbml=1&appId=765564420178321&version=v2.0";
# 			fjs.parentNode.insertBefore(js, fjs);
# 			}(document, 'script', 'facebook-jssdk'));</script>
# <div id="scrolling-div">
# <h3>NHL.cz na Facebooku <i class="fa fa-times pull-right" id="js-close-scrolling-div"></i></h3>
# <div class="fb-page" data-adapt-container-width="true" data-hide-cover="false" data-href="https://www.facebook.com/nhlcz" data-show-facepile="false" data-show-posts="false" data-small-header="true"><div class="fb-xfbml-parse-ignore"><blockquote cite="https://www.facebook.com/hokejcz"><a href="https://www.facebook.com/nhlcz">NHL</a></blockquote></div></div>
# </div>
# <div class="sticky-nav">
# <div class="header">
# <a class="logo" href="/">
# <img alt="Logo NHL.cz" src="/images/logo/logo_m.png" title="NHL.cz"/>
# </a>
# <div class="nav-main">
# <div class="container mod-full">
# <ul class="nav-main__level1">
# <li>
# <a href="/archiv-clanku" title="Články">Články</a>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/287" title="Video">Video</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/archiv-clanku/rubrika/286">Souhrny dne</a></li>
# <li><a href="/archiv-clanku/rubrika/275">Češi a Slováci</a></li>
# <li><a href="/archiv-clanku/rubrika/287">Góly dne</a></li>
# <li><a href="/historie-nhl/stranka/5003154">Bitky</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/sezona/zapasy" title="Zápasy a statistiky">Zápasy a statistiky</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/sezona/zapasy">Zápasy</a></li>
# <li><a href="/sezona/table">Tabulky</a>
# </li><li><a href="/historie-nhl/stranka/5003197">TV zápasy</a></li>
# <li><a href="/sezona/player-stats">Statistiky hráčů</a></li>
# <li><a href="/sezona/statistika-tymu">Statistiky týmů</a></li>
# <li><a href="/historie-nhl/stranka/5003214">Zranění hráči</a></li>
# <li><a href="/sezona/historicke-statistiky">Historické statistiky</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/sezona/tymy" title="Týmy">Týmy</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/sezona/roster">Soupisky</a></li>
# <li>
# <a href="/sezona/tymy">Týmy východní konference<i class="fa fa-chevron-down"></i></a>
# <div class="nav-main__sub">
# <div>
# <div class="col-100">
# <div class="row nav-main__teams-container">
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1987">
# <img src="https://www.hokej.cz/files/logos/boston.png"/>
# <span>Boston</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1989">
# <img src="https://www.hokej.cz/files/logos/buffalo.png"/>
# <span>Buffalo</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1990">
# <img src="https://www.hokej.cz/files/logos/carolina.png"/>
# <span>Carolina</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1991">
# <img src="https://www.hokej.cz/files/logos/columbus.png"/>
# <span>Columbus</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1992">
# <img src="https://www.hokej.cz/files/logos/detroit.png"/>
# <span>Detroit</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1993">
# <img src="https://www.hokej.cz/files/logos/2375.png"/>
# <span>Florida</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1994">
# <img src="https://www.hokej.cz/files/logos/montreal.png"/>
# <span>Montreal</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1995">
# <img src="https://www.hokej.cz/files/logos/njdevils.png"/>
# <span>New Jersey</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1996">
# <img src="https://www.hokej.cz/files/logos/nyislanders.png"/>
# <span>NY Islanders</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1997">
# <img src="https://www.hokej.cz/files/logos/nyrangers.png"/>
# <span>NY Rangers</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1998">
# <img src="https://www.hokej.cz/files/logos/ottawa-550.png"/>
# <span>Ottawa</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/1999">
# <img src="https://www.hokej.cz/files/logos/philadelphia.png"/>
# <span>Philadelphia</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2000">
# <img src="https://www.hokej.cz/files/logos/pittsburgh.png"/>
# <span>Pittsburgh</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2001">
# <img src="https://www.hokej.cz/files/logos/tampa.png"/>
# <span>Tampa Bay</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2002">
# <img src="https://www.hokej.cz/files/logos/2383.png"/>
# <span>Toronto</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2003">
# <img src="https://www.hokej.cz/files/logos/washington.png"/>
# <span>Washington</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/sezona/tymy">Týmy západní konference <i class="fa fa-chevron-down"></i></a>
# <div class="nav-main__sub">
# <div>
# <div class="col-100">
# <div class="row nav-main__teams-container">
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2004">
# <img src="https://www.hokej.cz/files/logos/anaheim.png"/>
# <span>Anaheim</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2005">
# <img src="https://www.hokej.cz/files/logos/arizona-logo-21-22-4.png"/>
# <span>Arizona</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2006">
# <img src="https://www.hokej.cz/files/logos/calgary.png"/>
# <span>Calgary</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2007">
# <img src="https://www.hokej.cz/files/logos/chicago.png"/>
# <span>Chicago</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2008">
# <img src="https://www.hokej.cz/files/logos/colorado.png"/>
# <span>Colorado</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2009">
# <img src="https://www.hokej.cz/files/logos/dallas.png"/>
# <span>Dallas</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2010">
# <img src="https://www.hokej.cz/files/logos/edmonton.png"/>
# <span>Edmonton</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2011">
# <img src="https://www.hokej.cz/files/logos/lakings.png"/>
# <span>Los Angeles</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2012">
# <img src="https://www.hokej.cz/files/logos/minesota.png"/>
# <span>Minnesota</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2013">
# <img src="https://www.hokej.cz/files/logos/nashville.png"/>
# <span>Nashville</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2014">
# <img src="https://www.hokej.cz/files/logos/sjsharks.png"/>
# <span>San Jose</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2730">
# <img src="https://www.hokej.cz/files/logos/logo-seattle.png"/>
# <span>Seattle</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2015">
# <img src="https://www.hokej.cz/files/logos/slblues.png"/>
# <span>St. Louis</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2016">
# <img src="https://www.hokej.cz/files/logos/vancouver.png"/>
# <span>Vancouver</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2655">
# <img src="https://www.hokej.cz/files/logos/cmqw6-Vegas-Golden-Knights.png"/>
# <span>Vegas</span>
# </a>
# </div>
# <div class="col-1_7 nav-main__team">
# <a href="/klub/2017">
# <img src="https://www.hokej.cz/files/logos/winnipeg.png"/>
# <span>Winnipeg</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li><a href="/historie-nhl/stranka/5003134">Kapitáni týmů</a></li>
# <li><a href="/historie-nhl/stranka/5003135">Trenéři</a></li>
# <li><a href="/historie-nhl/stranka/5003136">Generální manažeři</a></li>
# </ul></div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/275" title="Češi a Slováci">Češi a Slováci</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/archiv-clanku/rubrika/275">Zpravodajství</a></li>
# <li><a href="https://nhl.cz/sezona/player-stats/detailni?stats-menu-section=info&amp;stats-filter-season=2021&amp;stats-filter-competition=6733&amp;stats-playerFilter-country=cze">Statistiky Čechů</a></li>
# <li><a href="https://nhl.cz/sezona/player-stats/detailni?stats-filter-season=2021&amp;stats-filter-competition=6733&amp;stats-menu-section=info&amp;stats-playerFilter-country=svk">Statistiky Slováků</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/279" title="Další soutěže">Další soutěže</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/archiv-clanku/rubrika/279">AHL</a></li>
# <li><a href="/historie-nhl/stranka/5025008">Výsledky AHL</a></li>
# <li><a href="/historie-nhl/stranka/5025010">Tabulky AHL</a></li>
# <li><a href="/historie-nhl/stranka/5025009">Kanadské bodování AHL</a></li>
# <li><a href="/historie-nhl/stranka/5025011">Češi a Slováci v AHL</a></li>
# <li><a href="/archiv-clanku/rubrika/281">ECHL a nižší soutěže</a></li>
# <li><a href="/archiv-clanku/rubrika/280">Juniorské soutěže</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/historie-nhl/stranka/5003208" title="Rekordy">Rekordy</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/historie-nhl/stranka/5003208">Historické bodování Čechů</a></li>
# <li><a href="/historie-nhl/stranka/5003199">Nejproduktivnější hráči</a></li>
# <li><a href="/historie-nhl/stranka/5003201">Nejlepší střelci</a></li>
# <li><a href="/historie-nhl/stranka/5003205">Nejvíce bodů v sezóně</a></li>
# <li><a href="/historie-nhl/stranka/5003209">Nejvíce vítězných gólů</a></li>
# <li><a href="/historie-nhl/stranka/5003206">Hráči podle národnosti</a></li>
# <li><a href="/historie-nhl/stranka/5003207">Hráči podle měsíce narození</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/historie-nhl" title="Historie">Historie</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/historie-nhl">Přehled historie</a></li>
# <li><a href="/historie-nhl/stranka/5002679">Rekordy NHL</a></li>
# <li><a href="/historie-nhl/stranka/5002685">Vítězové základní části</a></li>
# <li><a href="/historie-nhl/stranka/5002826">Vítězové Stanley Cupu</a></li>
# <li><a href="/historie-nhl/stranka/5002686">Jedničky draftu NHL</a></li>
# <li><a href="/historie-nhl/stranka/5003133">Hvězdy týdne</a></li>
# <li><a href="/historie-nhl/stranka/5003140">Hvězdy měsíce</a></li>
# <li><a href="/oceneni-a-trofeje">Trofeje NHL</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/oceneni-a-trofeje" title="Ocenění a trofeje">Ocenění a trofeje</a>
# <div class="nav-main__sub">
# <div class="nav-main__level2-container">
# <div class="container">
# <div class="row">
# <div class="col-100">
# <ul class="nav-main__level2">
# <li><a href="/historie-nhl/stranka/5003133">Hvězdy týdne</a></li>
# <li><a href="/historie-nhl/stranka/5003140">Hvězdy měsíce</a></li>
# <li><a href="/oceneni-a-trofeje">Trofeje NHL</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# <div class="col-25">
# </div>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a href="/archiv-clanku/autor/40006" title="Petr Adler">Petr Adler</a>
# </li>
# <li>
# <a href="/archiv-clanku/autor/141" title="Jiří Lacina">Jiří Lacina</a>
# </li>
# </ul>
# </div>
# </div>
# <ul class="social">
# <li class="social-fb"><a href="https://www.facebook.com/nhlcz" target="_blank" title="facebook"><i class="fa fa-facebook"></i></a></li>
# <li class="social-tw"><a href="https://twitter.com/NHL_cz" target="_blank" title="twitter"><i class="fa fa-twitter"></i></a></li>
# <li class="social-gplus"><a href="https://plus.google.com/+hokejcz" target="_blank" title="google+"><i class="fa fa-google-plus"></i></a></li>
# <li class="social-rss"><a href="/rss/nhl" title="rss"><i class="fa fa-rss"></i></a></li>
# <li class="last">
# </li>
# </ul>
# <div class="dl-menuwrapper" id="dl-menu">
# <div class="dl-trigger">
# <div class="dl-bars">
# <span></span>
# <span></span>
# <span></span>
# </div>
# <span class="dl-title">menu</span>
# </div>
# <ul class="dl-menu">
# <li>
# <a href="/archiv-clanku" title="Články">Články</a>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/287" title="Video">Video</a>
# </li>
# <li>
# <a href="/sezona/zapasy" title="Zápasy a statistiky">Zápasy a statistiky</a>
# </li>
# <li>
# <a href="/sezona/tymy" title="Týmy">Týmy</a>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/275" title="Češi a Slováci">Češi a Slováci</a>
# </li>
# <li>
# <a href="/archiv-clanku/rubrika/279" title="Další soutěže">Další soutěže</a>
# </li>
# <li>
# <a href="/historie-nhl/stranka/5003208" title="Rekordy">Rekordy</a>
# </li>
# <li>
# <a href="/historie-nhl" title="Historie">Historie</a>
# </li>
# <li>
# <a href="/oceneni-a-trofeje" title="Ocenění a trofeje">Ocenění a trofeje</a>
# </li>
# <li>
# <a href="/archiv-clanku/autor/40006" title="Petr Adler">Petr Adler</a>
# </li>
# <li>
# <a href="/archiv-clanku/autor/141" title="Jiří Lacina">Jiří Lacina</a>
# </li>
# </ul>
# </div><!-- /dl-menuwrapper --> </div>
# </div>
# <div class="content-wrapper">
# <div class="container">
# <div class="header-bottom">
# <div class="search-all">
# <form action="/vyhledavani" method="get">
# <input name="q" placeholder="Vyhledat na webu …" type="text"/>
# <input type="submit" value=""/>
# </form>
# </div>
# <div class="search-person">
# <form action="/sezona/tymy" class="player-search" id="frm-playerSearch-form" method="post">
# <input id="frm-playerSearch-form-q" name="q" placeholder="Vyhledat hráče..." type="text"/>
# <input class="input-hide" id="frm-playerSearch-form-search" name="search" type="submit" value="Hledat"/>
# <div><input name="do" type="hidden" value="playerSearch-form-submit"/><!--[if IE]><input type=IEbug disabled style="display:none"><![endif]--></div>
# </form>
# <div id="snippet-playerSearch-"></div></div> </div>
# <div class="box-snow--bb-1 club-heading">
# <div class="container">
# <div class="row">
# <div class="col-50">
# <h1 class="page__heading">Zápasy a statistiky</h1>
# </div>
# <div class="col-30 club-heading__social-links">
# </div>
# <div class="club-heading__partner">
# </div>
# <div class="club-heading__partner">
# <span class="page__heading-logo">
# <a href="https://www.tipsport.cz/PartnerRedirectAction.do?pid=61&amp;sid=481&amp;bid=2264&amp;tid=9624" target="_blank">
# <img src="https://www.hokej.cz/files/logos/tipsport.png"/>
# </a>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="nav-tab">
# <div class="container row">
# <div class="col-100">
# <ul class="nav-tab__list">
# <li>
# <a class="active" href="/sezona/tymy">Týmy</a>
# </li>
# <li>
# <a href="/sezona/zapasy">Zápasy</a>
# </li>
# <li>
# <a href="/sezona/roster">Soupisky</a>
# </li>
# <li>
# <a href="/sezona/table">Tabulky</a>
# </li>
# <li>
# <a href="/sezona/statistika-tymu">Statistiky týmů</a>
# </li>
# <li>
# <a href="/sezona/player-stats">Statistiky hráčů</a>
# </li>
# <li>
# <a href="/sezona/historicke-statistiky">Historické statistiky</a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="container">
# <div class="row p-t-30">
# <div class="row m-b-30">
# <form action="/sezona/tymy" id="frm-teamList-filter-form" method="post">
# <div class="col-30">
# <select class="extended-select" id="frm-teamList-filter-form-season" name="season" onchange="this.form.submit();"><option selected="" value="2021">2021-2022</option><option value="2020">2020-2021</option><option value="2019">2019-2020</option><option value="2018">2018-2019</option><option value="2017">2017-2018</option><option value="2016">2016-2017</option><option value="2015">2015-2016</option><option value="2014">2014-2015</option><option value="2013">2013-2014</option><option value="2012">2012-2013</option><option value="2011">2011-2012</option><option value="2010">2010-2011</option><option value="2009">2009-2010</option><option value="2008">2008-2009</option><option value="2007">2007-2008</option><option value="2006">2006-2007</option><option value="2005">2005-2006</option><option value="2004">2004-2005</option><option value="2003">2003-2004</option><option value="2002">2002-2003</option><option value="2001">2001-2002</option><option value="2000">2000-2001</option><option value="1999">1999-2000</option><option value="1998">1998-1999</option><option value="1997">1997-1998</option><option value="1996">1996-1997</option><option value="1995">1995-1996</option><option value="1994">1994-1995</option><option value="1993">1993-1994</option><option value="1992">1992-1993</option><option value="1991">1991-1992</option><option value="1990">1990-1991</option><option value="1989">1989-1990</option><option value="1988">1988-1989</option><option value="1987">1987-1988</option><option value="1986">1986-1987</option><option value="1985">1985-1986</option><option value="1984">1984-1985</option><option value="1983">1983-1984</option><option value="1982">1982-1983</option><option value="1981">1981-1982</option><option value="1980">1980-1981</option><option value="1979">1979-1980</option><option value="1978">1978-1979</option><option value="1977">1977-1978</option><option value="1976">1976-1977</option><option value="1975">1975-1976</option><option value="1974">1974-1975</option><option value="1973">1973-1974</option><option value="1972">1972-1973</option><option value="1971">1971-1972</option><option value="1970">1970-1971</option><option value="1969">1969-1970</option><option value="1968">1968-1969</option><option value="1967">1967-1968</option><option value="1966">1966-1967</option><option value="1965">1965-1966</option><option value="1964">1964-1965</option><option value="1963">1963-1964</option><option value="1962">1962-1963</option><option value="1961">1961-1962</option><option value="1960">1960-1961</option><option value="1959">1959-1960</option><option value="1958">1958-1959</option><option value="1957">1957-1958</option><option value="1956">1956-1957</option><option value="1955">1955-1956</option><option value="1954">1954-1955</option><option value="1953">1953-1954</option><option value="1952">1952-1953</option><option value="1951">1951-1952</option><option value="1950">1950-1951</option><option value="1949">1949-1950</option><option value="1948">1948-1949</option><option value="1947">1947-1948</option><option value="1946">1946-1947</option><option value="1945">1945-1946</option><option value="1944">1944-1945</option><option value="1943">1943-1944</option><option value="1942">1942-1943</option><option value="1941">1941-1942</option><option value="1940">1940-1941</option><option value="1939">1939-1940</option><option value="1938">1938-1939</option><option value="1937">1937-1938</option><option value="1936">1936-1937</option><option value="1935">1935-1936</option><option value="1934">1934-1935</option><option value="1933">1933-1934</option><option value="1932">1932-1933</option><option value="1931">1931-1932</option><option value="1930">1930-1931</option><option value="1929">1929-1930</option><option value="1928">1928-1929</option><option value="1927">1927-1928</option><option value="1926">1926-1927</option><option value="1925">1925-1926</option><option value="1924">1924-1925</option><option value="1923">1923-1924</option><option value ...
# </div>
# <input class="input-hide" id="frm-teamList-filter-form-send" name="send" type="submit" value="Odeslat"/>
# <div><input name="do" type="hidden" value="teamList-filter-form-submit"/><!--[if IE]><input type=IEbug disabled style="display:none"><![endif]--></div>
# </form>
# </div>
# <div class="row row-extended p-t-20 m-b-30">
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2004">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fanaheim.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Anaheim Ducks</h2>
# </a>
# <a class="box-team__link" href="http://ducks.nhl.com/" target="_blank">ducks.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/AnaheimDucks"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/anaheimducks?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/anaheimducks"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2005">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Farizona-logo-21-22-4.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Arizona Coyotes</h2>
# </a>
# <a class="box-team__link" href="http://coyotes.nhl.com/" target="_blank">coyotes.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/ArizonaCoyotes"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/ArizonaCoyotes?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/arizonacoyotes/"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1987">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fboston.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Boston Bruins</h2>
# </a>
# <a class="box-team__link" href="http://bruins.nhl.com/" target="_blank">bruins.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLBruins"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/NHLBruins?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhlbruins"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1989">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fbuffalo.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Buffalo Sabres</h2>
# </a>
# <a class="box-team__link" href="http://sabres.nhl.com/" target="_blank">sabres.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/BuffaloSabres"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/BuffaloSabres?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/buffalosabres"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2006">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fcalgary.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Calgary Flames</h2>
# </a>
# <a class="box-team__link" href="http://flames.nhl.com/" target="_blank">flames.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLFlames"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/NHLFlames?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhlflames"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1990">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fcarolina.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Carolina Hurricanes</h2>
# </a>
# <a class="box-team__link" href="http://hurricanes.nhl.com" target="_blank">hurricanes.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLCanes"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/Hurricanes?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhlcanes"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2008">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fcolorado.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Colorado Avalanche</h2>
# </a>
# <a class="box-team__link" href="http://avalanche.nhl.com/" target="_blank">avalanche.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/Avalanche"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/coloradoavalanche?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/coloradoavalanche"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1991">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fcolumbus.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Columbus Blue Jackets</h2>
# </a>
# <a class="box-team__link" href="http://bluejackets.nhl.com/" target="_blank">bluejackets.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/BlueJacketsNHL"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/columbusbluejackets?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/bluejacketsnhl"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2009">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fdallas.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Dallas Stars</h2>
# </a>
# <a class="box-team__link" href="http://stars.nhl.com" target="_blank">stars.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/DallasStars"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/DallasStars?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/dallasstars"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1992">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fdetroit.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Detroit Red Wings</h2>
# </a>
# <a class="box-team__link" href="http://redwings.nhl.com/" target="_blank">redwings.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/DetroitRedWings"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/DETROITREDWINGS?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/detroitredwings"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2010">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fedmonton.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Edmonton Oilers</h2>
# </a>
# <a class="box-team__link" href="http://oilers.nhl.com" target="_blank">oilers.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/EdmontonOilers"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/Oilers.NHL?ref=ts&amp;fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/edmontonoilers"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1993">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2F2375.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Florida Panthers</h2>
# </a>
# <a class="box-team__link" href="http://panthers.nhl.com/" target="_blank">panthers.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://https://twitter.com/FlaPanthers"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/Flapanthers?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/flapanthers"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2007">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fchicago.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Chicago Blackhawks</h2>
# </a>
# <a class="box-team__link" href="http://blackhawks.nhl.com" target="_blank">blackhawks.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLBlackhawks"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/nhlblackhawks?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/NHLBlackhawks"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2011">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Flakings.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Los Angeles Kings</h2>
# </a>
# <a class="box-team__link" href="http://kings.nhl.com" target="_blank">kings.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/LAKings"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/LAKings?fref=ts&amp;rf=105676542799741"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/lakings"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2012">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fminesota.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Minnesota Wild</h2>
# </a>
# <a class="box-team__link" href="http://wild.nhl.com" target="_blank">wild.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/mnwild"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/minnesotawild?ref=ts&amp;fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/minnesotawild"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1994">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fmontreal.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Montreal Canadiens</h2>
# </a>
# <a class="box-team__link" href="http://canadiens.nhl.com/" target="_blank">canadiens.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/CanadiensMTL"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/canadiensmtl?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/CanadiensMTL"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2013">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fnashville.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Nashville Predators</h2>
# </a>
# <a class="box-team__link" href="http://predators.nhl.com/" target="_blank">predators.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/PredsNHL"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/nashvillepredators?ref=ts&amp;fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/officialnashvillepredators"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1995">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fnjdevils.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>New Jersey Devils</h2>
# </a>
# <a class="box-team__link" href="http://devils.nhl.com/" target="_blank">devils.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLDevils"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/NewJerseyDevils?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhldevils"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1996">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fnyislanders.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>New York Islanders</h2>
# </a>
# <a class="box-team__link" href="http://islanders.nhl.com/" target="_blank">islanders.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NYIslanders"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/NEWYORKISLANDERS?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/ny_islanders"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1997">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fnyrangers.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>New York Rangers</h2>
# </a>
# <a class="box-team__link" href="http://rangers.nhl.com/" target="_blank">rangers.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NYRangers"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/nyrangers?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nyrangers"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1998">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fottawa-550.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Ottawa Senators</h2>
# </a>
# <a class="box-team__link" href="http://senators.nhl.com/" target="_blank">senators.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/Senators"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/ottawasenators?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhlsenators"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/1999">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fphiladelphia.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Philadelphia Flyers</h2>
# </a>
# <a class="box-team__link" href="http://flyers.nhl.com/" target="_blank">flyers.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLFlyers"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/philadelphiaflyers?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/philadelphiaflyers"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2000">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fpittsburgh.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Pittsburgh Penguins</h2>
# </a>
# <a class="box-team__link" href="http://penguins.nhl.com/" target="_blank">penguins.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/penguins"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/penguins?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/penguins"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2014">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fsjsharks.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>San Jose Sharks</h2>
# </a>
# <a class="box-team__link" href="http://sharks.nhl.com/" target="_blank">sharks.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/SanJoseSharks"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/SanJoseSharks?ref=ts&amp;fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/sanjosesharksofficial"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2730">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Flogo-seattle.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Seattle Kraken</h2>
# </a>
# <a class="box-team__link" href="https://www.nhl.com/kraken" target="_blank">www.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/SeattleKraken"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/seattlekraken"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/seattlekraken/"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2015">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fslblues.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>St. Louis Blues</h2>
# </a>
# <a class="box-team__link" href="http://blues.nhl.com/" target="_blank">blues.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/StLouisBlues"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/St.LouisBlues?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/stlouisblues"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2001">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Ftampa.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Tampa Bay Lightning</h2>
# </a>
# <a class="box-team__link" href="http://lightning.nhl.com/" target="_blank">lightning.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/TBLightning"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/Lightning.NHL?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/tblightning"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2002">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2F2383.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Toronto Maple Leafs</h2>
# </a>
# <a class="box-team__link" href="http://mapleleafs.nhl.com/" target="_blank">mapleleafs.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/MapleLeafs"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/torontomapleleafs?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/torontomapleleafs"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2016">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fvancouver.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Vancouver Canucks</h2>
# </a>
# <a class="box-team__link" href="http://canucks.nhl.com" target="_blank">canucks.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/VanCanucks"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/Canucks?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/Canucks"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2655">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fcmqw6-Vegas-Golden-Knights.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Vegas Golden Knights</h2>
# </a>
# <a class="box-team__link" href="https://www.nhl.com/goldenknights" target="_blank">www.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="https://twitter.com/GoldenKnights"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://www.facebook.com/vegasgoldenknights/?ref=ts&amp;fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="https://www.instagram.com/vegasgoldenknights/?hl=cs"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2003">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fwashington.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Washington Capitals</h2>
# </a>
# <a class="box-team__link" href="http://capitals.nhl.com/" target="_blank">capitals.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/washcaps"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/WashingtonCapitals?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/washingtoncaps"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# <div class="col-25 box-team">
# <div class="box-team__container">
# <a class="box-team__head" href="/klub/2017">
# <img src="/min.php?file=https%3A%2F%2Fwww.hokej.cz%2Ffiles%2Flogos%2Fwinnipeg.png&amp;w=120&amp;h=120&amp;exact=1"/>
# <h2>Winnipeg Jets</h2>
# </a>
# <a class="box-team__link" href="http://jets.nhl.com/" target="_blank">jets.nhl.com</a>
# <div class="btn-container">
# <a class="btn btn-icon btn-black rounded" href="http://twitter.com/NHLJets"><i class="fa fa-twitter"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://facebook.com/nhljets?fref=ts"><i class="fa fa-facebook"></i></a>
# <a class="btn btn-icon btn-black rounded" href="http://instagram.com/nhljets"><i class="fa fa-instagram"></i></a>
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="banner m-b-10"><!-- #Zona:Homepage;#ID:2x15;billboard_bottom_1 -->
# <div class="cnc-ads cnc-ads--billboard_bottom">
# <div class="cnc-ads__within" id="cnc_billboard_bottom_1"></div>
# </div>
# </div>
# <div class="footer">
# <div class="container">
# <div class="row">
# <div class="col-25">
# <h2>NHL.cz</h2>
# <ul class="list">
# <li><a href="/archiv-clanku" title="Články">Články</a></li>
# <li><a href="/archiv-clanku/rubrika/287" title="Video">Video</a></li>
# <li><a href="/sezona/zapasy" title="Zápasy a statistiky">Zápasy a statistiky</a></li>
# <li><a href="/sezona/tymy" title="Týmy">Týmy</a></li>
# <li><a href="/archiv-clanku/rubrika/275" title="Češi a Slováci">Češi a Slováci</a></li>
# <li><a href="/archiv-clanku/rubrika/279" title="Další soutěže">Další soutěže</a></li>
# <li><a href="/historie-nhl/stranka/5003208" title="Rekordy">Rekordy</a></li>
# <li><a href="/historie-nhl" title="Historie">Historie</a></li>
# <li><a href="/oceneni-a-trofeje" title="Ocenění a trofeje">Ocenění a trofeje</a></li>
# <li><a href="/archiv-clanku/autor/40006" title="Petr Adler">Petr Adler</a></li>
# <li><a href="/archiv-clanku/autor/141" title="Jiří Lacina">Jiří Lacina</a></li>
# </ul> </div>
# <div class="col-25">
# <h2>Projekty</h2>
# <ul class="list">
# <li><a href="http://www.hokej.cz/">Hokej.cz</a></li>
# </ul>
# <h2>Organizace</h2>
# <ul class="list">
# <li><a href="http://www.bpa.cz">BPA sport marketing</a></li>
# <li><a href="http://www.cslh.cz">ČSLH</a></li>
# <li><a href="http://www.iihf.com">IIHF</a></li>
# <li><a href="http://www.nhl.com">NHL</a></li>
# </ul>
# </div>
# <div class="col-25 footer__social">
# <h2>Sociální sítě</h2>
# <ul class="list-unstyled">
# <li><a class="btn-facebook" href="https://www.facebook.com/nhlcz"><i class="fa fa-facebook"></i> facebook</a></li>
# <li><a class="btn-google-plus" href="https://plus.google.com/+hokejcz"><i class="fa fa-google-plus"></i> google+</a></li>
# <li><a class="btn-twitter" href="https://twitter.com/NHL_cz"><i class="fa fa-twitter"></i> twitter</a></li>
# </ul> </div>
# <div class="col-25">
# <a class="isport-link" href="https://isport.blesk.cz/zoh-2018-korea" target="_blank"><img alt="Logo iSport.cz" class="isport-logo" src="/images/logo/isport.png" title="iSport.cz"/></a>
# <ul class="list">
# <li><a href="https://isport.blesk.cz/zoh-2018-hokej">ZOH</a></li>
# <li><a href="https://isport.blesk.cz/program-zoh-2018">PROGRAM</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="imprint">
# <div class="container">
# <div class="row">
# <div class="col-100 text-center">
# <a href="/rss/nhl">RSS</a> | <a href="/historie-nhl/stranka/5003239">Kontakt</a> | <a href="/vseobecne-obchodni-podminky-a-pravidla">Všeobecné obchodní podmínky a pravidla</a> | <a href="/cookies">Cookies</a> | <a href="javascript:Didomi.preferences.show()">Nastavení soukromí</a> | <a href="/historie-nhl/stranka/5003240">Reklama</a> -
# Provozovatel <a href="http://www.bpa.cz/">BPA sport marketing a.s.</a> ve spolupráci s <a href="http://esportsmedia.cz/">eSports, s.r.o.</a>
# <p style="margin-top:10px">ISSN 1214-5718 | dotazy na redakci: redakce@nhl.cz, obchod/reklama: obchod@hokej.cz, technický provoz: webmaster@hokej.cz</p>
# <p style="margin-top:10px">© Copyright - Všechna loga a známky NHL, loga a známky týmů NHL, jakožto další vlastnické materiály včetně log konferencí a obrázků Stanley Cupu jsou vlastnictvím NHL, NHL Enterprises, L.P. a příslušných týmů. © NHL Enterprises, L.P. Všechna práva vyhrazena.
#
# 								</p></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>window.jQuery || document.write('<script src="/js/vendor/jquery-1.11.0.min.js"><\/script>')</script>
# <script src="/webtemp/jsloader-5d74b4f520bc.js?1634812855" type="text/javascript"></script>
# <script type="text/javascript">
# 			$(function() {
#
# 				$('form.player-search').submit(function(e) {
# 					$(this).netteAjax(e);
# 					return false;
# 				});
#
# 				var replacedValue = "--VALUE--";
# 				var searchLink = "\/sezona\/tymy?playerSearch-q=--VALUE--&do=playerSearch-search"
# 				var searchTimeout;
#
# 				$('form.player-search').on('keyup', 'input[type="text"]', function(e) {
# 					var $this = $(this);
# 					var query = $this.val();
#
# 					if (searchTimeout) {
# 						clearTimeout(searchTimeout);
# 					}
#
# 					if (query.length < 2 || !isAllowedKey(e.which)) {
# 						return true;
# 					}
#
# 					searchTimeout = setTimeout(function () {
# 						var link = searchLink.replace(replacedValue, $this.val());
# 						$.nette.ajax(link);
# 					}, 150);
# 				}).attr("autocomplete", "off");
#
# 				function isAllowedKey(key) {
# 					if (key === 0 || key === 13) {
# 						return false;
# 					}
#
# 					return true;
# 				}
# 			});
# 		</script>
# <script data-cookiecategory="ga-analytics" type="text/plain">
#
#         var _gaq = _gaq || [];
#         _gaq.push(['_setAccount', 'UA-54672655-2']);
#         _gaq.push(['_trackPageview']);
#
#         _gaq.push(['trac2._setAccount', 'UA-55779224-1']);
#         _gaq.push(['trac2._trackPageview']);
#
#       (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#          var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#         })();
#
# </script>
# <script>
#   window.addEventListener('load', () => {
#     const consent = Didomi.getUserConsentStatus('publishers-Kqq3iPge', 'c:bpasport-8kEcj3eh');
#     if(!consent) return;
#     const currentScript = document.querySelector('[data-cookiecategory="ga-analytics"]');
#     currentScript.removeAttribute('data-cookiecategory');
#     currentScript.setAttribute('type','text/javascript');
#     const freshScript = document.createElement('script');
#     freshScript.innerHTML = currentScript.innerHTML;
#     currentScript.parentElement.replaceChild(freshScript, currentScript);
#   })
# </script>
# <!-- (C)2000-2013 Gemius SA - gemiusAudience / nhl.cz / Homepage -->
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var pp_gemius_identifier = '..GQy3fGv0PyqZ4k1NqbxLR3HbG_7PtdKhBx0CewDc3.57';
# var pp_gemius_use_cmp = true;
# // lines below shouldn't be edited
# function gemius_pending(i) { window[i] = window[i] || function() {var x = window[i+'_pdata'] = window[i+'_pdata'] || []; x[x.length]=arguments;};};
# gemius_pending('gemius_hit'); gemius_pending('gemius_event'); gemius_pending('pp_gemius_hit'); gemius_pending('pp_gemius_event');
# (function(d,t) {try {var gt=d.createElement(t),s=d.getElementsByTagName(t)[0],l='http'+((location.protocol=='https:')?'s':''); gt.setAttribute('async','async');
# gt.setAttribute('defer','defer'); gt.src=l+'://spir.hit.gemius.pl/xgemius.js'; s.parentNode.insertBefore(gt,s);} catch (e) {}})(document,'script');
# //--><!]]>
# </script>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "9883551" });
#     (function() {
#      var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#      s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#      el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=9883551&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script src="https://contentz.mkt61.net/lp/static/js/iMAWebCookie.js?1ddd0b1-156cc89f072-be7239722bf9e6184ab469c11075fd86&amp;h=www.pages06.net" type="text/javascript"></script>
# <link href="https://s3-eu-west-1.amazonaws.com/hokej.cz/scripts/ad.css" rel="StyleSheet" type="text/css"/>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NQH6GKW" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- #Zona:Homepage;#ID:2x33;outof_page -->
# <div id="cnc_out_of_page"></div>'];
#     </body>
# </html>

# %%
team_info_list = codes.findAll('a', {'class':'box-team__head'})
code_list = [x["href"] for x in team_info_list]
team_list = [h2.text for h2 in codes.findAll('h2')]
dict_team_codes = {team_list[i]: code_list[i] for i in range(len(code_list))}
dict_team_codes
# Out:
# {'Anaheim Ducks': '/klub/2004',
#  'Arizona Coyotes': '/klub/2005',
#  'Boston Bruins': '/klub/1987',
#  'Buffalo Sabres': '/klub/1989',
#  'Calgary Flames': '/klub/2006',
#  'Carolina Hurricanes': '/klub/1990',
#  'Colorado Avalanche': '/klub/2008',
#  'Columbus Blue Jackets': '/klub/1991',
#  'Dallas Stars': '/klub/2009',
#  'Detroit Red Wings': '/klub/1992',
#  'Edmonton Oilers': '/klub/2010',
#  'Florida Panthers': '/klub/1993',
#  'Chicago Blackhawks': '/klub/2007',
#  'Los Angeles Kings': '/klub/2011',
#  'Minnesota Wild': '/klub/2012',
#  'Montreal Canadiens': '/klub/1994',
#  'Nashville Predators': '/klub/2013',
#  'New Jersey Devils': '/klub/1995',
#  'New York Islanders': '/klub/1996',
#  'New York Rangers': '/klub/1997',
#  'Ottawa Senators': '/klub/1998',
#  'Philadelphia Flyers': '/klub/1999',
#  'Pittsburgh Penguins': '/klub/2000',
#  'San Jose Sharks': '/klub/2014',
#  'Seattle Kraken': '/klub/2730',
#  'St. Louis Blues': '/klub/2015',
#  'Tampa Bay Lightning': '/klub/2001',
#  'Toronto Maple Leafs': '/klub/2002',
#  'Vancouver Canucks': '/klub/2016',
#  'Vegas Golden Knights': '/klub/2655',
#  'Washington Capitals': '/klub/2003',
#  'Winnipeg Jets': '/klub/2017'}

# %%
#sezony zatim rucne neprijde mi ze by to slo od nekud vycist
#2017 je 2017/2018 atd.
season_codes = {'2017': '6049', '2018': '6270', '2019': '6494', '2020': '6673','2021': '6733'}

# %% [markdown]
# ## How it works: one team and one team so far
#
# ## Sorry za mess, nektery variables jsou zbytecny, uklidim to pozdeji

# %% [markdown]
# ##### Needs to be made to be more automated later
# #### Later used: TOI = Team of Interest

# %%
team_of_interest = "Boston Bruins"
code_of_interest = dict_team_codes[team_of_interest]
season_of_interest = '2021'
code_of_season = season_codes[season_of_interest]
soup = getSoup(f'https://nhl.cz{code_of_interest}/zapasy?matchList-filter-season={season_of_interest}&matchList-filter-competition={code_of_season}')
#soup

# %%
all_games = soup.findAll('tr')

# %% [markdown]
# ### Goals in a list

# %%
goals = [int(td.text) for td in soup.findAll('td', {'class':'preview__score'})]
goals[:5]
# Out:
# [3, 1, 6, 3, 1]

# %% [markdown]
# ### Teams in a list

# %%
teams = [span.text for span in soup.findAll('span', {'class':'preview__name--long'})]
teams[:5]
# Out:
# ['Boston Bruins',
#  'Dallas Stars',
#  'Philadelphia Flyers',
#  'Boston Bruins',
#  'Buffalo Sabres']

# %% [markdown]
# ### Overtime or not

# %%
OT = []
for game in all_games:
    ot = game.find('span', {'class':'dot dot__blue'})
    if ot is None:
        OT.append(0)
    else:
        OT.append(1)
print(OT[:7])
# Out:
# [0, 0, 0, 0, 0, 0, 1]

# %% [markdown]
# ### Game ID in a list

# %%
game_ids_list = soup.find_all("a", href=lambda value: value and value.startswith("/zapas/"))
game_ids = [x["href"] for x in game_ids_list][::2]
game_ids[:5]
# Out:
# ['/zapas/2897006',
#  '/zapas/2897032',
#  '/zapas/2897045',
#  '/zapas/2897063',
#  '/zapas/2897081']

# %% [markdown]
# ### Putting it in a dataframe

# %%
aux_dictionary = {'game_id':game_ids, 'team_home': teams[::2], 'team_away': teams[1::2],
    'goals_home': goals[::2], 'goals_away': goals[1::2], 'OT': OT} 
df = pd.DataFrame(aux_dictionary)
df.head()
# Out:
#           game_id            team_home        team_away  goals_home  \
# 0  /zapas/2897006        Boston Bruins     Dallas Stars           3
# 1  /zapas/2897032  Philadelphia Flyers    Boston Bruins           6
# 2  /zapas/2897045       Buffalo Sabres    Boston Bruins           1
# 3  /zapas/2897063        Boston Bruins  San Jose Sharks           4
# 4  /zapas/2897081     Florida Panthers    Boston Bruins           4
#
#    goals_away  OT
# 0           1   0
# 1           3   0
# 2           4   0
# 3           3   0
# 4           1   0

# %% [markdown]
# ### Adding some more variables that might be useful

# %%
df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 0), 'points_home'] = 3
df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 1), 'points_home'] = 2
df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 1), 'points_home'] = 1
df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 0), 'points_home'] = 0

df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 0), 'points_away'] = 0
df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 1), 'points_away'] = 1
df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 1), 'points_away'] = 2
df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 0), 'points_away'] = 3

df.head()
# Out:
#           game_id            team_home        team_away  goals_home  \
# 0  /zapas/2897006        Boston Bruins     Dallas Stars           3
# 1  /zapas/2897032  Philadelphia Flyers    Boston Bruins           6
# 2  /zapas/2897045       Buffalo Sabres    Boston Bruins           1
# 3  /zapas/2897063        Boston Bruins  San Jose Sharks           4
# 4  /zapas/2897081     Florida Panthers    Boston Bruins           4
#
#    goals_away  OT  points_home  points_away
# 0           1   0          3.0          0.0
# 1           3   0          3.0          0.0
# 2           4   0          0.0          3.0
# 3           3   0          3.0          0.0
# 4           1   0          3.0          0.0

# %% [markdown]
# ### Adding variable whether the team of interest is a home team

# %%
df.loc[df["team_home"] == team_of_interest, 'TOI_home'] = 1
df.loc[df["team_home"] != team_of_interest, 'TOI_home'] = 0

# %% [markdown]
# ### Adding how many points TOI received

# %%
df.loc[(df["TOI_home"] == 1), 'TOI_points'] = df["points_home"]
df.loc[(df["TOI_home"] == 0), 'TOI_points'] = df["points_away"]

df.loc[(df["TOI_home"] == 1), 'TOI_goals_scored'] = df["goals_home"]
df.loc[(df["TOI_home"] == 0), 'TOI_goals_scored'] = df["goals_away"]
df.loc[(df["TOI_home"] == 1), 'TOI_goals_rec'] = df["goals_away"]
df.loc[(df["TOI_home"] == 0), 'TOI_goals_rec'] = df["goals_home"]

# %% [markdown]
# ### Adding Output Variable: the result of our TOI

# %%
df.loc[df["OT"] == 1, 'TOI_result'] = "OT"
df.loc[(df["TOI_home"] == 1) & (df["points_home"] == 3), 'TOI_result'] = "W"
df.loc[(df["TOI_home"] == 1) & (df["points_home"] == 0), 'TOI_result'] = "L"
df.loc[(df["TOI_home"] == 0) & (df["points_home"] == 3), 'TOI_result'] = "L"
df.loc[(df["TOI_home"] == 0) & (df["points_home"] == 0), 'TOI_result'] = "W"

# %%
df.loc[(df["TOI_home"] == 1), 'other_team'] = df["team_away"]
df.loc[(df["TOI_home"] == 0), 'other_team'] = df["team_home"]
df.head()
# Out:
#           game_id            team_home        team_away  goals_home  \
# 0  /zapas/2897006        Boston Bruins     Dallas Stars           3
# 1  /zapas/2897032  Philadelphia Flyers    Boston Bruins           6
# 2  /zapas/2897045       Buffalo Sabres    Boston Bruins           1
# 3  /zapas/2897063        Boston Bruins  San Jose Sharks           4
# 4  /zapas/2897081     Florida Panthers    Boston Bruins           4
#
#    goals_away  OT  points_home  points_away  TOI_home  TOI_points  \
# 0           1   0          3.0          0.0       1.0         3.0
# 1           3   0          3.0          0.0       0.0         0.0
# 2           4   0          0.0          3.0       0.0         3.0
# 3           3   0          3.0          0.0       1.0         3.0
# 4           1   0          3.0          0.0       0.0         0.0
#
#    TOI_goals_scored  TOI_goals_rec TOI_result           other_team
# 0               3.0            1.0          W         Dallas Stars
# 1               3.0            6.0          L  Philadelphia Flyers
# 2               4.0            1.0          W       Buffalo Sabres
# 3               4.0            3.0          W      San Jose Sharks
# 4               1.0            4.0          L     Florida Panthers

# %% [markdown]
# ### Adding variables - sum of last 20 games

# %%
TOI_points_tot = [None] * 20
TOI_goals_scored_tot = [None] * 20
TOI_goals_rec_tot = [None] * 20
for x in range(len(df)):
    if x > 19:
        TOI_points_tot.append(int(df[['TOI_points']][x-20:x].sum()))
        TOI_goals_scored_tot.append(int(df[['TOI_goals_scored']][x-20:x].sum()))
        TOI_goals_rec_tot.append(int(df[['TOI_goals_rec']][x-20:x].sum()))
df['TOI_points_tot'] = TOI_points_tot
df['TOI_goals_scored_tot'] = TOI_goals_scored_tot
df['TOI_goals_rec_tot'] = TOI_goals_rec_tot

df.iloc[19:25, 8:]
# Out:
# [None,
#  35,
#  33,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  34,
#  37,
#  34,
#  37,
#  37,
#  37,
#  37,
#  39,
#  36,
#  39,
#  39,
#  39]

# %%
#tady jen neco zkousim
df[['TOI_home']][:20]
int(df[['TOI_points']][0:20].sum())
# Out:
# 35

# %% [markdown]
# Takhle bude vypadat df, akorat v nim bude dat za vice sezon

# %% [markdown]
# ## Creating the dataset later used for modellig

# %% [markdown]
# ## ke kazdemu zapasu:
# - jeho id
# - nazev druheho tymu
# - vysledek TOI (output variable)
# - jestli hraje TOI doma
# - kolik ziskal TOI bodu v poslednich X (20/30) zapasech
# - kolik dal TOI golu v poslednich X (20/30) zapasech
# - kolik dostal TOI golu v poslednich X (20/30) zapasech
#
#
#     - toto bude jeste vse potreba i pro druhy tym s kterym je prave ten zapas
#     - tyhle radky plus radky o druhem tymu by uz meli jit nakrmit do modelu a to by melo byt vsechno

# %%
n_of_games = 20 #the number of previous games we will take into account, myslim ze 20 je tak optimalni

# %%
df_model = df[['game_id','TOI_result','other_team','TOI_home', 'TOI_points_tot', 'TOI_goals_scored_tot', 'TOI_goals_rec_tot']][20:].copy()
df_model
# Out:
#            game_id TOI_result            other_team  TOI_home  TOI_points_tot  \
# 20  /zapas/2897351         OT   Tampa Bay Lightning       1.0            35.0
# 21  /zapas/2897379         OT     Vancouver Canucks       0.0            33.0
# 22  /zapas/2897387          W       Edmonton Oilers       0.0            34.0
# 23  /zapas/2897403          W        Calgary Flames       0.0            34.0
# 24  /zapas/2897426          L  Vegas Golden Knights       1.0            34.0
# ..             ...        ...                   ...       ...             ...
# 77  /zapas/2898234          W      New York Rangers       1.0            34.0
# 78  /zapas/2897458          W    Montreal Canadiens       0.0            34.0
# 79  /zapas/2898259          W      Florida Panthers       1.0            34.0
# 80  /zapas/2898274          W        Buffalo Sabres       1.0            35.0
# 81  /zapas/2898287          L   Toronto Maple Leafs       0.0            38.0
#
#     TOI_goals_scored_tot  TOI_goals_rec_tot
# 20                  59.0               53.0
# 21                  58.0               55.0
# 22                  56.0               51.0
# 23                  55.0               52.0
# 24                  55.0               51.0
# ..                   ...                ...
# 77                  63.0               54.0
# 78                  62.0               52.0
# 79                  64.0               53.0
# 80                  66.0               54.0
# 81                  69.0               50.0
#
# [62 rows x 7 columns]

# %% [markdown]
# # Turning it into OOP

# %%
def create_link(team_of_interest,season_of_interest):
    code_of_season = season_codes[season_of_interest]
    code_of_interest = dict_team_codes[team_of_interest]
    return f'https://nhl.cz{code_of_interest}/zapasy?matchList-filter-season={season_of_interest}&matchList-filter-competition={code_of_season}'
create_link('Boston Bruins', '2021'),
# Out:
# ('https://nhl.cz/klub/1987/zapasy?matchList-filter-season=2021&matchList-filter-competition=6733',)

# %%
#tady bude Class co idealne vrati df ktery pak pouzijem, muzem z toho vytisknout i nakej v prubehu tak jako KUK
class One_team_season:
   
    def __init__(self,link,team):
        self.link = link
        self.team = team
    
    def get_soup(self):
        r = requests.get(self.link)
        if r.status_code == 200:
            r.encoding='UTF-8'
            return BeautifulSoup(r.text)
        else:
            raise Exception(f'Cannot access the url. Returning status_code {r.status_code}')
            
    def get_goals(self,soup):
        return [int(td.text) for td in soup.findAll('td', {'class':'preview__score'})]
    
    def get_teams(self,soup):
        return [span.text for span in soup.findAll('span', {'class':'preview__name--long'})]
    
    def get_OT(self,soup):
        all_games = soup.findAll('tr')
        OT = []
        for game in all_games:
            ot = game.find('span', {'class':'dot dot__blue'})
            if ot is None:
                OT.append(0)
            else:
                OT.append(1)
        return OT
    
    def get_game_IDs(self,soup):
        game_ids_list = soup.find_all("a", href=lambda value: value and value.startswith("/zapas/"))
        game_ids = [x["href"] for x in game_ids_list][::2]
        return game_ids
    
    def create_df(self):
        soup = self.get_soup()
        goals = self.get_goals(soup)
        teams = self.get_teams(soup)
        OT = self.get_OT(soup)
        game_ids = self.get_game_IDs(soup)
        aux_dictionary = {'game_id':game_ids, 'team_home': teams[::2], 'team_away': teams[1::2],
        'goals_home': goals[::2], 'goals_away': goals[1::2], 'OT': OT} 
        df = pd.DataFrame(aux_dictionary)
        return df
    
    def create_model_df(self):
        df = self.create_df()
        df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 0), 'points_home'] = 3
        df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 1), 'points_home'] = 2
        df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 1), 'points_home'] = 1
        df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 0), 'points_home'] = 0

        df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 0), 'points_away'] = 0
        df.loc[(df["goals_home"] > df["goals_away"]) & (df["OT"] == 1), 'points_away'] = 1
        df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 1), 'points_away'] = 2
        df.loc[(df["goals_home"] < df["goals_away"]) & (df["OT"] == 0), 'points_away'] = 3
        
        df.loc[df["team_home"] == self.team, 'TOI_home'] = 1
        df.loc[df["team_home"] != self.team, 'TOI_home'] = 0
        
        df.loc[(df["TOI_home"] == 1), 'TOI_points'] = df["points_home"]
        df.loc[(df["TOI_home"] == 0), 'TOI_points'] = df["points_away"]

        df.loc[(df["TOI_home"] == 1), 'TOI_goals_scored'] = df["goals_home"]
        df.loc[(df["TOI_home"] == 0), 'TOI_goals_scored'] = df["goals_away"]
        df.loc[(df["TOI_home"] == 1), 'TOI_goals_rec'] = df["goals_away"]
        df.loc[(df["TOI_home"] == 0), 'TOI_goals_rec'] = df["goals_home"]
        
        df.loc[df["OT"] == 1, 'TOI_result'] = "OT"
        df.loc[(df["TOI_home"] == 1) & (df["points_home"] == 3), 'TOI_result'] = "W"
        df.loc[(df["TOI_home"] == 1) & (df["points_home"] == 0), 'TOI_result'] = "L"
        df.loc[(df["TOI_home"] == 0) & (df["points_home"] == 3), 'TOI_result'] = "L"
        df.loc[(df["TOI_home"] == 0) & (df["points_home"] == 0), 'TOI_result'] = "W"
        
        df.loc[(df["TOI_home"] == 1), 'other_team'] = df["team_away"]
        df.loc[(df["TOI_home"] == 0), 'other_team'] = df["team_home"]
        
        return df

# %%
boston = One_team_season('https://nhl.cz/klub/1987/zapasy?matchList-filter-season=2021&matchList-filter-competition=6733',
                        'Boston Bruins')
boston.create_df()
# Out:
#            game_id            team_home         team_away  goals_home  \
# 0   /zapas/2897006        Boston Bruins      Dallas Stars           3
# 1   /zapas/2897032  Philadelphia Flyers     Boston Bruins           6
# 2   /zapas/2897045       Buffalo Sabres     Boston Bruins           1
# 3   /zapas/2897063        Boston Bruins   San Jose Sharks           4
# 4   /zapas/2897081     Florida Panthers     Boston Bruins           4
# ..             ...                  ...               ...         ...
# 77  /zapas/2898234        Boston Bruins  New York Rangers           3
# 78  /zapas/2897458   Montreal Canadiens     Boston Bruins           3
# 79  /zapas/2898259        Boston Bruins  Florida Panthers           4
# 80  /zapas/2898274        Boston Bruins    Buffalo Sabres           5
# 81  /zapas/2898287  Toronto Maple Leafs     Boston Bruins           5
#
#     goals_away  OT
# 0            1   0
# 1            3   0
# 2            4   0
# 3            3   0
# 4            1   0
# ..         ...  ..
# 77           1   0
# 78           5   0
# 79           2   0
# 80           0   0
# 81           2   0
#
# [82 rows x 6 columns]

# %%
boston.create_model_df()
# Out:
#            game_id            team_home         team_away  goals_home  \
# 0   /zapas/2897006        Boston Bruins      Dallas Stars           3
# 1   /zapas/2897032  Philadelphia Flyers     Boston Bruins           6
# 2   /zapas/2897045       Buffalo Sabres     Boston Bruins           1
# 3   /zapas/2897063        Boston Bruins   San Jose Sharks           4
# 4   /zapas/2897081     Florida Panthers     Boston Bruins           4
# ..             ...                  ...               ...         ...
# 77  /zapas/2898234        Boston Bruins  New York Rangers           3
# 78  /zapas/2897458   Montreal Canadiens     Boston Bruins           3
# 79  /zapas/2898259        Boston Bruins  Florida Panthers           4
# 80  /zapas/2898274        Boston Bruins    Buffalo Sabres           5
# 81  /zapas/2898287  Toronto Maple Leafs     Boston Bruins           5
#
#     goals_away  OT  points_home  points_away  TOI_home  TOI_points  \
# 0            1   0          3.0          0.0       1.0         3.0
# 1            3   0          3.0          0.0       0.0         0.0
# 2            4   0          0.0          3.0       0.0         3.0
# 3            3   0          3.0          0.0       1.0         3.0
# 4            1   0          3.0          0.0       0.0         0.0
# ..         ...  ..          ...          ...       ...         ...
# 77           1   0          3.0          0.0       1.0         3.0
# 78           5   0          0.0          3.0       0.0         3.0
# 79           2   0          3.0          0.0       1.0         3.0
# 80           0   0          3.0          0.0       1.0         3.0
# 81           2   0          3.0          0.0       0.0         0.0
#
#     TOI_goals_scored  TOI_goals_rec TOI_result           other_team
# 0                3.0            1.0          W         Dallas Stars
# 1                3.0            6.0          L  Philadelphia Flyers
# 2                4.0            1.0          W       Buffalo Sabres
# 3                4.0            3.0          W      San Jose Sharks
# 4                1.0            4.0          L     Florida Panthers
# ..               ...            ...        ...                  ...
# 77               3.0            1.0          W     New York Rangers
# 78               5.0            3.0          W   Montreal Canadiens
# 79               4.0            2.0          W     Florida Panthers
# 80               5.0            0.0          W       Buffalo Sabres
# 81               2.0            5.0          L  Toronto Maple Leafs
#
# [82 rows x 14 columns]

# %%
#dale je potreba: mergnout datasety pro X poslednich sezon dohromady pro TOI
#a creatnout ten df s info ze poslednich 20 zapasu
#asi bude nejlepsi kdyz se takovej dataset udela pro vsech 32 tymu protoze ty data pak budou potreba na training
#team of interest nak poresit
#hodit treba i ten create link nejak do toho Classu, aby pak stacil:
#"boston = One_team_season('Boston Bruins', 2021)"... a ono to vrati ten DF

# %% [markdown]
# ### Calculating Home Advantage

# %%
sum_wins_home = sum(df["goals_home"] > df["goals_away"])
sum_wins_away = sum(df["goals_home"] < df["goals_away"])
 
home_winrate = sum_wins_home/(sum_wins_home+sum_wins_away)
home_winrate
# Out:
# 0.5121951219512195

# %% [markdown]
# ### List of all the teams

# %%
distinct_teams = []
for team in teams:
    if team not in distinct_teams:
        distinct_teams.append(team)
print(distinct_teams)
# Out:
# ['Boston Bruins', 'Dallas Stars', 'Philadelphia Flyers', 'Buffalo Sabres', 'San Jose Sharks', 'Florida Panthers', 'Carolina Hurricanes', 'Detroit Red Wings', 'Toronto Maple Leafs', 'Ottawa Senators', 'Edmonton Oilers', 'New Jersey Devils', 'Montreal Canadiens', 'Calgary Flames', 'New York Rangers', 'Vancouver Canucks', 'Nashville Predators', 'Tampa Bay Lightning', 'Vegas Golden Knights', 'New York Islanders', 'Minnesota Wild', 'Washington Capitals', 'Winnipeg Jets', 'Anaheim Ducks', 'Colorado Avalanche', 'Arizona Coyotes', 'Seattle Kraken', 'Pittsburgh Penguins', 'Los Angeles Kings', 'Columbus Blue Jackets', 'Chicago Blackhawks', 'St. Louis Blues']

# %%
df
# Out:
#            game_id            team_home         team_away  goals_home  \
# 0   /zapas/2897006        Boston Bruins      Dallas Stars           3
# 1   /zapas/2897032  Philadelphia Flyers     Boston Bruins           6
# 2   /zapas/2897045       Buffalo Sabres     Boston Bruins           1
# 3   /zapas/2897063        Boston Bruins   San Jose Sharks           4
# 4   /zapas/2897081     Florida Panthers     Boston Bruins           4
# ..             ...                  ...               ...         ...
# 77  /zapas/2898234        Boston Bruins  New York Rangers           3
# 78  /zapas/2897458   Montreal Canadiens     Boston Bruins           3
# 79  /zapas/2898259        Boston Bruins  Florida Panthers           4
# 80  /zapas/2898274        Boston Bruins    Buffalo Sabres           5
# 81  /zapas/2898287  Toronto Maple Leafs     Boston Bruins           5
#
#     goals_away  OT  points_home  points_away  TOI_home  TOI_points  \
# 0            1   0          3.0          0.0       1.0         3.0
# 1            3   0          3.0          0.0       0.0         0.0
# 2            4   0          0.0          3.0       0.0         3.0
# 3            3   0          3.0          0.0       1.0         3.0
# 4            1   0          3.0          0.0       0.0         0.0
# ..         ...  ..          ...          ...       ...         ...
# 77           1   0          3.0          0.0       1.0         3.0
# 78           5   0          0.0          3.0       0.0         3.0
# 79           2   0          3.0          0.0       1.0         3.0
# 80           0   0          3.0          0.0       1.0         3.0
# 81           2   0          3.0          0.0       0.0         0.0
#
#     TOI_goals_scored  TOI_goals_rec TOI_result           other_team  \
# 0                3.0            1.0          W         Dallas Stars
# 1                3.0            6.0          L  Philadelphia Flyers
# 2                4.0            1.0          W       Buffalo Sabres
# 3                4.0            3.0          W      San Jose Sharks
# 4                1.0            4.0          L     Florida Panthers
# ..               ...            ...        ...                  ...
# 77               3.0            1.0          W     New York Rangers
# 78               5.0            3.0          W   Montreal Canadiens
# 79               4.0            2.0          W     Florida Panthers
# 80               5.0            0.0          W       Buffalo Sabres
# 81               2.0            5.0          L  Toronto Maple Leafs
#
#     TOI_points_tot  TOI_goals_scored_tot  TOI_goals_rec_tot
# 0              NaN                   NaN                NaN
# 1              NaN                   NaN                NaN
# 2              NaN                   NaN                NaN
# 3              NaN                   NaN                NaN
# 4              NaN                   NaN                NaN
# ..             ...                   ...                ...
# 77            34.0                  63.0               54.0
# 78            34.0                  62.0               52.0
# 79            34.0                  64.0               53.0
# 80            35.0                  66.0               54.0
# 81            38.0                  69.0               50.0
#
# [82 rows x 17 columns]

# %% [markdown]
# ### Kolik bodů získal tým celkem

# %%
#tady je problem že je to zatím pro jeden tým určený tím boston.
#Až budem vyjíždět týmy je třeba upravit
toi=boston.create_model_df()
points_home = toi.groupby(['team_home'])['points_home'].sum().reset_index()
points_away = toi.groupby(['team_away'])['points_away'].sum().reset_index()
points_home.rename(columns = {'team_home':'team'}, inplace = True)
points_away.rename(columns = {'team_away':'team'}, inplace = True)
tp = points_home.merge(points_away, left_on='team', right_on='team')
total_poins = tp["points_home"] + tp["points_away"]
tp["points_total"] = points_total
tp.drop(tp[tp.points_total < 15].index, inplace=True)
if len(tp) != 1:
            raise Exception('There is more than 1 team left')
tp
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1280/3254932582.py in <module>
#      10 #tp.drop(tp[tp.points_total < 15].index, inplace=True)
#      11 if len(tp) != 1:
# ---> 12             raise Exception('There is more than 1 team left')
#      13 tp
#
# Exception: There is more than 1 team left

# %%
if len(tp) != 1:
            raise Exception('There is more than 1 team left')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1280/2063256349.py in <module>
#       1 if len(tp) != 1:
# ----> 2             raise Exception('There is more than 1 team left')
#
# Exception: There is more than 1 team left
